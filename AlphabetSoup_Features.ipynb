# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
plt.scatter(application_df["ASK_AMT"], application_df["IS_SUCCESSFUL"])
plt.xlabel("Ask Amount")
plt.ylabel("Success")
#plt.xticks(application_df["ASK_AMT"])
plt.xscale("log")
plt.show()

# %%
plt.scatter(application_df["USE_CASE"], application_df["IS_SUCCESSFUL"])
plt.xlabel("Use Case")
plt.ylabel("Success")
plt.show()

# %%
plt.scatter(application_df["AFFILIATION"], application_df["IS_SUCCESSFUL"])
plt.xlabel("Affiliation")
plt.ylabel("Success")
plt.xticks(application_df["AFFILIATION"], rotation=90)
plt.show()

# %%
plt.scatter(application_df["ORGANIZATION"], application_df["IS_SUCCESSFUL"])
plt.xlabel("Organization")
plt.ylabel("Success")
plt.show()
